# %%
import plotly.plotly as py
import plotly.graph_objs as go

# %%
nfc_east = [
    go.Scatterpolar(
      r = [33927142, 19209750, 37354110, 11189060, 9216568, 9509739, 2900000],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Dallas Cowboys'
    ),
    go.Scatterpolar(
      r = [36658292, 6629300, 34676919, 44166418, 2632378, 9683320, 1672500],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Philadelphia Eagles'
    ),
    go.Scatterpolar(
      r = [6724656, 29518000, 15085197, 42129323, 6821390, 15060097, 2200000],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'New York Giants'
    ),
    go.Scatterpolar(
      r = [11701129, 23749223, 23821562, 12165426, 4992784, 23041044, 3433990],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Washington Redskins'
    )
]

layout = go.Layout(
  legend=dict(x=0, y=1.2),
  polar = dict(
    radialaxis = dict(
      visible = True,
      range = [0, 60000000]
    )
  ),
  showlegend = True
)

nfc_east_fig = go.Figure(data=nfc_east, layout=layout)
py.iplot(nfc_east_fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~brandon.morgan01/68.embed" height="525px" width="100%"></iframe>

# %%
nfc_north = [
    go.Scatterpolar(
      r = [6650881, 12759404, 15584918, 34787881, 6652941, 26281424, 6845000],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Detroit Lions'
    ),
    go.Scatterpolar(
      r = [20570010, 30592325, 25863683, 45501020, 3448492, 20155499, 5942500],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Chicago Bears'
    ),
    go.Scatterpolar(
      r = [2637451, 14870489, 31530360, 57984542, 1021204, 9848673, 6283723],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Green Bay Packers'
    ),
    go.Scatterpolar(
      r = [36673595, 17844387, 22721901, 50805762, 8094025, 33394168, 3230000],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Minnesota Vikings'
    )
]

layout = go.Layout(
  legend=dict(x=0, y=1.2),
  polar = dict(
    radialaxis = dict(
      visible = True,
      range = [0, 60000000]
    )
  ),
  showlegend = True
)

nfc_north_fig = go.Figure(data=nfc_north, layout=layout)
py.iplot(nfc_north_fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~brandon.morgan01/66.embed" height="525px" width="100%"></iframe>

# %%
nfc_south = [
    go.Scatterpolar(
      r = [43518046, 14481157, 24861346, 35085558, 5479454, 12693975, 2470882],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Carolina Panthers'
    ),
    go.Scatterpolar(
      r = [27506682, 14615854, 34396062, 40235926, 7700840, 14010759, 3280000],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'New Orleans Saints'
    ),
    go.Scatterpolar(
      r = [20579225, 4516688, 31191773, 48643072, 2054409, 28978875, 5374019],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Atlanta Falcons'
    ),
    go.Scatterpolar(
      r = [48968992, 11180589, 22898202, 54008704, 3515801, 13315734, 3889412],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Tampa Bay Buccaneers'
    )
]

layout = go.Layout(
  legend=dict(x=0, y=1.2),
  polar = dict(
    radialaxis = dict(
      visible = True,
      range = [0, 60000000]
    )
  ),
  showlegend = True
)

nfc_south_fig = go.Figure(data=nfc_south, layout=layout)
py.iplot(nfc_south_fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~brandon.morgan01/70.embed" height="525px" width="100%"></iframe>

# %%
nfc_west = [
    go.Scatterpolar(
      r = [41341683, 14735904, 29363516, 23812960, 8408319, 33361188, 7578551],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Los Angeles Rams'
    ),
    go.Scatterpolar(
      r = [10624024, 25474109, 22377225, 45751240, 5182604, 12245760, 3197537],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Seattle Seahawks'
    ),
    go.Scatterpolar(
      r = [20709028, 10550120, 41852671, 12815949, 5560586, 12035363, 3134138],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'San Francisco 49ers'
    ),
    go.Scatterpolar(
      r = [22548633, 13513467, 2602729, 33736256, 6795917, 26042262, 3674485],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Arizona Cardinals'
    )
]

layout = go.Layout(
  legend=dict(x=0, y=1.2),
  polar = dict(
    radialaxis = dict(
      visible = True,
      range = [0, 60000000]
    )
  ),
  showlegend = True
)

nfc_west_fig = go.Figure(data=nfc_west, layout=layout)
py.iplot(nfc_west_fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~brandon.morgan01/72.embed" height="525px" width="100%"></iframe>

# %%
afc_east = [
    go.Scatterpolar(
      r = [33927142, 19209750, 37354110, 11189060, 9216568, 9509739, 2900000],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'New England Patriots'
    ),
    go.Scatterpolar(
      r = [36658292, 6629300, 34676919, 44166418, 2632378, 9683320, 1672500],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Miami Dolphins'
    ),
    go.Scatterpolar(
      r = [6724656, 29518000, 15085197, 42129323, 6821390, 15060097, 2200000],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'New York Jets'
    ),
    go.Scatterpolar(
      r = [11701129, 23749223, 23821562, 12165426, 4992784, 23041044, 3433990],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Buffalo Bills'
    )
]

layout = go.Layout(
  legend=dict(x=0, y=1.2),
  polar = dict(
    radialaxis = dict(
      visible = True,
      range = [0, 60000000]
    )
  ),
  showlegend = True
)

afc_east_fig = go.Figure(data=afc_east, layout=layout)
py.iplot(afc_east_fig)

# %%
afc_north = [
    go.Scatterpolar(
      r = [6650881, 12759404, 15584918, 34787881, 6652941, 26281424, 6845000],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Baltimore Ravens'
    ),
    go.Scatterpolar(
      r = [20570010, 30592325, 25863683, 45501020, 3448492, 20155499, 5942500],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Cincinnati Bengals'
    ),
    go.Scatterpolar(
      r = [2637451, 14870489, 31530360, 57984542, 1021204, 9848673, 6283723],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Cleveland Browns'
    ),
    go.Scatterpolar(
      r = [36673595, 17844387, 22721901, 50805762, 8094025, 33394168, 3230000],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Pittsburgh Steelers'
    )
]

layout = go.Layout(
  legend=dict(x=0, y=1.2),
  polar = dict(
    radialaxis = dict(
      visible = True,
      range = [0, 60000000]
    )
  ),
  showlegend = True
)

afc_north_fig = go.Figure(data=afc_north, layout=layout)
py.iplot(afc_north_fig)

# %%
afc_south = [
    go.Scatterpolar(
      r = [43518046, 14481157, 24861346, 35085558, 5479454, 12693975, 2470882],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Indianapolis Colts'
    ),
    go.Scatterpolar(
      r = [27506682, 14615854, 34396062, 40235926, 7700840, 14010759, 3280000],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Jacksonville Jaguars'
    ),
    go.Scatterpolar(
      r = [20579225, 4516688, 31191773, 48643072, 2054409, 28978875, 5374019],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Tennessee Titans'
    ),
    go.Scatterpolar(
      r = [48968992, 11180589, 22898202, 54008704, 3515801, 13315734, 3889412],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Houston Texans'
    )
]

layout = go.Layout(
  legend=dict(x=0, y=1.2),
  polar = dict(
    radialaxis = dict(
      visible = True,
      range = [0, 60000000]
    )
  ),
  showlegend = True
)

afc_south_fig = go.Figure(data=afc_south, layout=layout)
py.iplot(afc_south_fig)

# %%
afc_west = [
    go.Scatterpolar(
      r = [41341683, 14735904, 29363516, 23812960, 8408319, 33361188, 7578551],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Denver Broncos'
    ),
    go.Scatterpolar(
      r = [10624024, 25474109, 22377225, 45751240, 5182604, 12245760, 3197537],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Los Angeles Chargers'
    ),
    go.Scatterpolar(
      r = [20709028, 10550120, 41852671, 12815949, 5560586, 12035363, 3134138],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Oakland Raiders'
    ),
    go.Scatterpolar(
      r = [22548633, 13513467, 2602729, 33736256, 6795917, 26042262, 3674485],
      theta = ["Defensive Line", "Linebacker", "Offensive Line", "Passing", "Rushing", "Secondary", "Special Teams"],
      fill = 'toself',
      name = 'Kansas City Chiefs'
    )
]

layout = go.Layout(
  legend=dict(x=0, y=1.2),
  polar = dict(
    radialaxis = dict(
      visible = True,
      range = [0, 60000000]
    )
  ),
  showlegend = True
)

afc_west_fig = go.Figure(data=afc_west, layout=layout)
py.iplot(afc_west_fig)
